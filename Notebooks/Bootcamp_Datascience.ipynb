# %% [markdown]
# <a href="https://colab.research.google.com/github/liliansampaio/Producao_hospitalar_Brasil/blob/main/Notebooks/Bootcamp_Datascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Caderno de exploração dos dados do DataSUS 2008 para frente

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dados = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/A144756189_28_143_208.csv", encoding= "ISO-8859-1",
                    skiprows = 3, sep = ";", skipfooter = 12,
                    thousands = ".", decimal = ",")
dados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2021/Fev    2021/Mar         Total
# 0          11 Rondônia        -        -  ...  6039419.59  4732441.04  996411254.68
# 1              12 Acre        -        -  ...  2272733.90  1137341.65  450048530.47
# 2          13 Amazonas        -        -  ... 13679358.06  6799060.80 1917247936.05
# 3           14 Roraima        -        -  ...  3044798.77  2381844.31  328876965.09
# 4              15 Pará        -        -  ... 23343222.94 13069564.31 4705309002.29
#
# [5 rows x 287 columns]

# %%
dengue_pri = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/A055321189_28_143_208.csv", encoding= "ISO-8859-1",
                    skiprows = 3, sep = ";", skipfooter = 17,
                    thousands = ".", decimal = ",")
dengue_pri
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#          UF de notificação    2007    2008  ...    2012    2013   Total
# 0              11 Rondônia    3128    5644  ...    3194    8485   63573
# 1                  12 Acre     526    2228  ...    2259    2467   80035
# 2              13 Amazonas    1938    7530  ...    5359   17545  103757
# 3               14 Roraima     913    4928  ...    1845     933   20510
# 4                  15 Pará   13958   15620  ...   16327    8941   94155
# 5                 16 Amapá    3631    1207  ...    1533    1683   15783
# 6             17 Tocantins   12820   10349  ...   11795    8698   66107
# 7              21 Maranhão   13345    5510  ...    5270    3489   45617
# 8                 22 Piauí    9906    2464  ...   12326    5004   50721
# 9                 23 Ceará   34395   48600  ...   54991   29974  257664
# 10  24 Rio Grande do Norte   13067   28885  ...   26643   16663  115808
# 11              25 Paraíba   10788    7806  ...    8577   13114   58357
# 12           26 Pernambuco   22600   18798  ...   31096    7159  131688
# 13              27 Alagoas   10623   13136  ...   27488   10599  118530
# 14              28 Sergipe    1431   21554  ...    4622     822   33363
# 15                29 Bahia    9485   33969  ...   48227   60381  332904
# 16         31 Minas Gerais   28555   49307  ...   30121  415068  824112
# 17       32 Espírito Santo    6815   25857  ...   11462   66468  205694
# 18       33 Rio de Janeiro   56417  200039  ...  178515  208419  837135
# 19            35 São Paulo  115309   11726  ...   28093  216398  692736
# 20               41 Paraná   27274    1860  ...    4579   65907  168000
# 21       42 Santa Catarina     157      82  ...      93     305    1018
# 22    43 Rio Grande do Sul     423     134  ...     155     448    5166
# 23   50 Mato Grosso do Sul   70322     759  ...    9277   78072  241031
# 24          51 Mato Grosso   16598    6783  ...   32848   34912  185192
# 25                52 Goiás   14853   35533  ...   23856  130542  372483
# 26     53 Distrito Federal    1254    1351  ...    1814   19738   42148
#
# [27 rows x 9 columns]

# %%
dengue_seg = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/A154006189_28_143_208.csv", encoding= "ISO-8859-1",
                    skiprows = 4, sep = ";", skipfooter = 20,
                    thousands = ".", decimal = ",")
dengue_seg
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#          UF de notificação 2013    2014    2015  ...    2019    2020  2021    Total
# 0              11 Rondônia   20    1994    2250  ...     990    3940     1    19844
# 1                  12 Acre   13   28464    6067  ...   10192    8049    77    64336
# 2              13 Amazonas   30    6318    3662  ...    3986    6195    12    33943
# 3               14 Roraima   10    1128    1110  ...    1605     570     -     5028
# 4                  15 Pará   21    4540    7853  ...    5397    3732     -    44031
# 5                 16 Amapá    1    2181    3400  ...     198      41     -     9366
# 6             17 Tocantins   40    3677    8005  ...   13752    2272     1    43643
# 7              21 Maranhão    -    2640    8003  ...    5641    2566     -    52084
# 8                 22 Piauí    2    7699    7742  ...    8052    2220     -    38257
# 9                 23 Ceará   30   22855   63596  ...   16306   23737     7   219907
# 10  24 Rio Grande do Norte   30   11576   22945  ...   32080    7169    14   162225
# 11              25 Paraíba   18    5637   23188  ...   18876    6701     1   105356
# 12           26 Pernambuco   19   10498  111368  ...   38044   21499    11   263637
# 13              27 Alagoas   28   13360   27294  ...   20998    2445     1    88732
# 14              28 Sergipe    2    2260    9258  ...    6047    1905     -    23952
# 15                29 Bahia   29   13964   55557  ...   68203   83350     5   308803
# 16         31 Minas Gerais  144   58256  192815  ...  478491   85243    17  1400513
# 17       32 Espírito Santo  108   19110   35408  ...   65046    7304     -   187546
# 18       33 Rio de Janeiro   52    7846   73705  ...   32075    4502     -   232474
# 19            35 São Paulo   56  226969  749772  ...  444381  210693    90  1863440
# 20               41 Paraná   66   22775   45859  ...   45763  266213   112   447414
# 21       42 Santa Catarina    -     137    4529  ...    2157   12016     2    24374
# 22    43 Rio Grande do Sul    -     150    1722  ...    1626    4017     3    11027
# 23   50 Mato Grosso do Sul   30    3397   31990  ...   65381   52729     8   208657
# 24          51 Mato Grosso   61    7183   21524  ...   11176   34768    15   112797
# 25                52 Goiás  291   92905  168934  ...  120548   59768    15   728067
# 26     53 Distrito Federal    9   13609   10245  ...   39584   51375    42   141200
#
# [27 rows x 11 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...    2021/Mar          Total
# 22   43 Rio Grande do Sul        -  ... 37798832.80 12764391179.92
# 23  50 Mato Grosso do Sul        -  ...  4035989.77  2324525096.33
# 24         51 Mato Grosso        -  ...  8835890.09  2180119781.15
# 25               52 Goiás        -  ... 24867001.02  4973572261.43
# 26    53 Distrito Federal        -  ... 14731938.43  2592422853.56
#
# [5 rows x 287 columns]

# %%
dados
# Out:
#       Unidade da Federação  1992/Mar  ...     2021/Mar          Total
# 0              11 Rondônia         -  ...   4732441.04   996411254.68
# 1                  12 Acre         -  ...   1137341.65   450048530.47
# 2              13 Amazonas         -  ...   6799060.80  1917247936.05
# 3               14 Roraima         -  ...   2381844.31   328876965.09
# 4                  15 Pará         -  ...  13069564.31  4705309002.29
# 5                 16 Amapá         -  ...    989155.40   309860092.59
# 6             17 Tocantins         -  ...    928756.84  1020028272.64
# 7              21 Maranhão         -  ...  17294509.11  3871069498.04
# 8                 22 Piauí         -  ...   9542151.53  2280888802.74
# 9                 23 Ceará         -  ...  17173151.55  6591836650.18
# 10  24 Rio Grande do Norte         -  ...   8733455.36  2660122027.15
# 11              25 Paraíba         -  ...  12517894.05  2614919044.63
# 12           26 Pernambuco         -  ...  39472738.81  8581189975.91
# 13              27 Alagoas         -  ...   8180887.21  2236415402.51
# 14              28 Sergipe         -  ...   3081081.42  1215853015.00
# 15                29 Bahia         -  ...  31314602.44  9791541570.52
# 16         31 Minas Gerais         -  ...  79780838.00 20418737536.66
# 17       32 Espírito Santo         -  ...  15606368.11  3405850698.58
# 18       33 Rio de Janeiro         -  ...  49149884.48 10337389922.09
# 19            35 São Paulo  40243.16  ... 177408317.71 41396408548.81
# 20               41 Paraná         -  ...  43480729.07 14681514706.67
# 21       42 Santa Catarina         -  ...  19375822.56  7835011163.40
# 22    43 Rio Grande do Sul         -  ...  37798832.80 12764391179.92
# 23   50 Mato Grosso do Sul         -  ...   4035989.77  2324525096.33
# 24          51 Mato Grosso         -  ...   8835890.09  2180119781.15
# 25                52 Goiás         -  ...  24867001.02  4973572261.43
# 26     53 Distrito Federal         -  ...  14731938.43  2592422853.56
#
# [27 rows x 287 columns]

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
dados["2008/Ago"]
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42500830.29
# 19   180005050.15
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21054991.27
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26641365.101481482

# %%
dados.plot(x = 'Unidade da Federação', y = '2008/Ago')

# %%
dados.plot(x = 'Unidade da Federação', y = '2008/Ago', kind = 'bar', figsize = (10, 7))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


ax = dados.plot(x = 'Unidade da Federação', y = '2008/Ago', kind = 'bar', figsize = (10, 7))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title("Valor total por unidade da federação")
plt.show()

# %% [markdown]
# #Desafio 1: Escolher um título mais descritivo, que passe a mensagem adequada.
#
# #Desafio 2: Faça um gráfico para um mês mais recente

# %% [markdown]
# **#Desafio 1: Resolução**

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


ax = dados.plot(x = 'Unidade da Federação', y = '2008/Ago', kind = 'bar', figsize = (10, 7))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title("Valor total dos procedimentos hospitalares do SUS por unidade da federação", fontsize = 15)
plt.show()

# %% [markdown]
# **#Desafio 2: Resolução**

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


ax = dados.plot(x = 'Unidade da Federação', y = '2021/Mar', kind = 'bar', figsize = (10, 7))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title("Valor total dos procedimentos hospitalares do SUS por unidade da federação", fontsize = 15)
plt.show()

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  '2020/Ago',
#  '2020/Set',
#  '2020/Out',
#  '2020/Nov',
#  '2020/Dez',
#  '2021/Jan',
#  '2021/Fev',
#  '2021/Mar',
#  'Total']

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2021/Mar         Total
# 0          11 Rondônia   4209.37  ...  4732441.04  996411254.68
# 1              12 Acre  10470.07  ...  1137341.65  450048530.47
# 2          13 Amazonas  35752.72  ...  6799060.80 1917247936.05
# 3           14 Roraima   4785.91  ...  2381844.31  328876965.09
# 4              15 Pará 181159.29  ... 13069564.31 4705309002.29
#
# [5 rows x 166 columns]

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2021/Mar          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   4732441.04   996411254.68
# 12 Acre                  10470.07   14001.71  ...   1137341.65   450048530.47
# 13 Amazonas              35752.72   45570.64  ...   6799060.80  1917247936.05
# 14 Roraima                4785.91   11858.63  ...   2381844.31   328876965.09
# 15 Pará                 181159.29  433414.74  ...  13069564.31  4705309002.29
# 16 Amapá                 33672.74  104822.98  ...    989155.40   309860092.59
# 17 Tocantins              4113.76   76633.06  ...    928756.84  1020028272.64
# 21 Maranhão             385330.18 1018352.93  ...  17294509.11  3871069498.04
# 22 Piauí                220788.25  353468.67  ...   9542151.53  2280888802.74
# 23 Ceará                357904.65  572356.18  ...  17173151.55  6591836650.18
# 24 Rio Grande do Norte  134605.36  272088.08  ...   8733455.36  2660122027.15
# 25 Paraíba               97352.78  368130.43  ...  12517894.05  2614919044.63
# 26 Pernambuco           400640.85 1088340.42  ...  39472738.81  8581189975.91
# 27 Alagoas              104243.75  174024.90  ...   8180887.21  2236415402.51
# 28 Sergipe               27453.63   78565.19  ...   3081081.42  1215853015.00
# 29 Bahia                135146.36  448349.75  ...  31314602.44  9791541570.52
# 31 Minas Gerais         971394.37 2861781.50  ...  79780838.00 20418737536.66
# 32 Espírito Santo        57408.11  284224.80  ...  15606368.11  3405850698.58
# 33 Rio de Janeiro       469469.34  921646.57  ...  49149884.48 10337389922.09
# 35 São Paulo           1665349.90 4434168.64  ... 177408317.71 41396408548.81
# 41 Paraná               554800.22 1431708.01  ...  43480729.07 14681514706.67
# 42 Santa Catarina       693955.05 1092964.12  ...  19375822.56  7835011163.40
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  37798832.80 12764391179.92
# 50 Mato Grosso do Sul   199556.12  573675.41  ...   4035989.77  2324525096.33
# 51 Mato Grosso           63562.50  232444.62  ...   8835890.09  2180119781.15
# 52 Goiás                179395.82  418053.58  ...  24867001.02  4973572261.43
# 53 Distrito Federal     191951.47  769966.25  ...  14731938.43  2592422853.56
#
# [27 rows x 165 columns]

# %%
usaveis["2019/Ago"]
# Out:
# Unidade da Federação
# 11 Rondônia                8909111.89
# 12 Acre                    2981072.98
# 13 Amazonas               16493719.52
# 14 Roraima                 3181321.82
# 15 Pará                   36462011.47
# 16 Amapá                   2173060.89
# 17 Tocantins               7140062.79
# 21 Maranhão               31374933.66
# 22 Piauí                  17833872.84
# 23 Ceará                  51672585.01
# 24 Rio Grande do Norte    23073542.40
# 25 Paraíba                19863848.57
# 26 Pernambuco             71735983.26
# 27 Alagoas                17668105.59
# 28 Sergipe                10075280.52
# 29 Bahia                  77884805.29
# 31 Minas Gerais          161774658.77
# 32 Espírito Santo         29318260.49
# 33 Rio de Janeiro         83624113.30
# 35 São Paulo             303584114.00
# 41 Paraná                127174381.95
# 42 Santa Catarina         64503540.72
# 43 Rio Grande do Sul      98566147.88
# 50 Mato Grosso do Sul     19217982.14
# 51 Mato Grosso            16532335.42
# 52 Goiás                  38533573.53
# 53 Distrito Federal       21133361.51
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Dez     3711660.71
# 2021/Jan     3005561.16
# 2021/Fev     2272733.90
# 2021/Mar     1137341.65
# Total      450048530.47
# Name: 12 Acre, Length: 165, dtype: float64

# %%
usaveis.plot(figsize=(12,6))

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
usaveis.T.plot(figsize=(10,6))

# %%
usaveis = usaveis.drop("Total", axis=1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Fev    2021/Mar
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  6039419.59  4732441.04
# 12 Acre               10470.07  14001.71  ...  2272733.90  1137341.65
# 13 Amazonas           35752.72  45570.64  ... 13679358.06  6799060.80
# 14 Roraima             4785.91  11858.63  ...  3044798.77  2381844.31
# 15 Pará              181159.29 433414.74  ... 23343222.94 13069564.31
#
# [5 rows x 164 columns]

# %%
usaveis.T.plot(figsize=(10,6))

# %% [markdown]
# # **AULA 2**
#
# #Desafio 1: reposicionar a legenda. Dentro? Fora? Onde?
#
# #Desafio 2: Selecionar 5 estados para plotar

# %% [markdown]
# **#Desafio 1: Reposicionamento da legenda**

# %%
uso = usaveis.T.plot(figsize=(10,6))
uso.legend(loc = 'upper right', fontsize = 5)

# %% [markdown]
# **#Desafio 2: Selecionar 5 estados para plotar**

# %%
estado = usaveis.T[['33 Rio de Janeiro', '25 Paraíba', '13 Amazonas', '35 São Paulo', '41 Paraná']]
estado.plot(figsize=(10,6))

# %%
estado = usaveis.T[['33 Rio de Janeiro', '25 Paraíba', '13 Amazonas', '35 São Paulo', '41 Paraná']]
estado.plot(figsize=(10,6))

# %% [markdown]
# # **AULA 3**

# %%
usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.index
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.T[:5]
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  ...   52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37  10470.07  ...  179395.82            191951.47
# 2007/Set                 16397.03  14001.71  ...  418053.58            769966.25
# 2007/Out                133645.19  86200.85  ... 1198730.25           2165619.56
# 2007/Nov                346912.84 301323.68  ... 2712117.54           3813256.48
# 2007/Dez                711758.31 769612.36  ... 9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
usaveis[:5]
# Out:
#                       2007/Ago  2007/Set  ...    2021/Fev    2021/Mar
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  6039419.59  4732441.04
# 12 Acre               10470.07  14001.71  ...  2272733.90  1137341.65
# 13 Amazonas           35752.72  45570.64  ... 13679358.06  6799060.80
# 14 Roraima             4785.91  11858.63  ...  3044798.77  2381844.31
# 15 Pará              181159.29 433414.74  ... 23343222.94 13069564.31
#
# [5 rows x 164 columns]

# %%
usaveis[:7].T.plot(figsize=(10,6))

# %%
import numpy as np
np.random.seed(687942)

usaveis.sample(n=7)
# Out:
#                         2007/Ago   2007/Set  ...     2021/Fev    2021/Mar
# Unidade da Federação                         ...
# 32 Espírito Santo       57408.11  284224.80  ...  25669612.63 15606368.11
# 31 Minas Gerais        971394.37 2861781.50  ... 119877417.15 79780838.00
# 24 Rio Grande do Norte 134605.36  272088.08  ...  18186942.80  8733455.36
# 17 Tocantins             4113.76   76633.06  ...    416534.32   928756.84
# 53 Distrito Federal    191951.47  769966.25  ...  19004029.87 14731938.43
# 50 Mato Grosso do Sul  199556.12  573675.41  ...  11428462.42  4035989.77
# 16 Amapá                33672.74  104822.98  ...   1534733.18   989155.40
#
# [7 rows x 164 columns]

# %%
usaveis["total"] = usaveis.sum(axis=1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Mar         total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  4732441.04  996410650.35
# 12 Acre               10470.07  14001.71  ...  1137341.65  450047246.65
# 13 Amazonas           35752.72  45570.64  ...  6799060.80 1917245104.64
# 14 Roraima             4785.91  11858.63  ...  2381844.31  328876551.40
# 15 Pará              181159.29 433414.74  ... 13069564.31 4705290466.69
#
# [5 rows x 165 columns]

# %%
ordenado_por_total = usaveis.sort_values("total", ascending = False)
ordenado_por_total = ordenado_por_total.drop("total", axis=1)
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set  ...     2021/Fev     2021/Mar
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 268193064.06 177408317.71
# 31 Minas Gerais       971394.37 2861781.50  ... 119877417.15  79780838.00
# 41 Paraná             554800.22 1431708.01  ...  83130175.37  43480729.07
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  84404640.00  37798832.80
# 33 Rio de Janeiro     469469.34  921646.57  ...  60873103.08  49149884.48
#
# [5 rows x 164 columns]

# %%
ordenado_por_total[:5].T.plot(figsize=(10,6))

# %% [markdown]
# # **AULA 3**
#
# #Desafio 1: Escolher uma palete de cores mais adequada com o matplotlib (OK)
# #Desafio 2: Adicionar uma coluna mostrando a região (Norte, Nordeste, Sul, Suldeste e Centro-Oeste) de cada estado (OK)
# #Desafio 3: Formatar o gráfico de custo, deixando ele mais agradável (OK)
# #Desafio 4: Adicione mais um estado aos 05 estados existentes no gráfico e plot (OK)
# #Desafio 5: corte o ponto de maior valor do gráfico (OK)
# #Desafio 5.1: Buscar os casos de dengue no Brasil(época de maior número de casos e regiões mais atingidas) e ver se os picos de alguns estados em fevereiro e verão de modo geral, pode ser reflexos dos casos de Dengue (OK).
# #Desafio 6: Plotar o gráfico dos custos apenas dos estados da região sudeste e verificar se os picos de 2013/Fev teve comportamento similar em todos os demais estados da região (OK).
# #Desafio 7: Adicionar mais um estado novamente e tire suas conclusões sobre estados comparando com os demais. Tire suas conclusões e compartilhe.

# %% [markdown]
# #Desafio 5: Corte o ponto maior valor do gráfico

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %% [markdown]
# #Desafio 1: Escolher uma palete de cores mais adequada com o matplotlib

# %% [markdown]
# #Desafio 3: Formatar o gráfico de custo, deixando ele mais agradável

# %% [markdown]
# #Desafio 4: Adicione mais um estado aos 05 estados existentes no gráfico e plot

# %%
ordenado_por_total.index
# Out:
# Index(['35 São Paulo', '31 Minas Gerais', '41 Paraná', '43 Rio Grande do Sul',
#        '33 Rio de Janeiro', '29 Bahia', '26 Pernambuco', '42 Santa Catarina',
#        '23 Ceará', '52 Goiás', '15 Pará', '21 Maranhão', '32 Espírito Santo',
#        '24 Rio Grande do Norte', '25 Paraíba', '53 Distrito Federal',
#        '50 Mato Grosso do Sul', '22 Piauí', '27 Alagoas', '51 Mato Grosso',
#        '13 Amazonas', '28 Sergipe', '17 Tocantins', '11 Rondônia', '12 Acre',
#        '14 Roraima', '16 Amapá'],
#       dtype='object', name='Unidade da Federação')

# %%
import matplotlib.pyplot as plt


ax = ordenado_por_total.T[['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '32 Espírito Santo', '13 Amazonas', '53 Distrito Federal']].plot(cmap = 'plasma', grid = True, figsize = (10,7))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.ylabel('Valor total por atendimento')
plt.title('Valor total dos procedimentos hospitalares do SUS por unidade da federação', fontsize = 15)
plt.legend(bbox_to_anchor=(1, 0.8))
plt.show()

# %% [markdown]
# #Desafio 2: Adicionar uma coluna mostrando a região (Norte, Nordeste, Sul, Suldeste e Centro-Oeste) de cada estado

# %%
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2021/Mar          total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   4732441.04   996410650.35
# 12 Acre                  10470.07   14001.71  ...   1137341.65   450047246.65
# 13 Amazonas              35752.72   45570.64  ...   6799060.80  1917245104.64
# 14 Roraima                4785.91   11858.63  ...   2381844.31   328876551.40
# 15 Pará                 181159.29  433414.74  ...  13069564.31  4705290466.69
# 16 Amapá                 33672.74  104822.98  ...    989155.40   309837994.87
# 17 Tocantins              4113.76   76633.06  ...    928756.84  1019990254.88
# 21 Maranhão             385330.18 1018352.93  ...  17294509.11  3871010362.58
# 22 Piauí                220788.25  353468.67  ...   9542151.53  2280874839.37
# 23 Ceará                357904.65  572356.18  ...  17173151.55  6591825335.83
# 24 Rio Grande do Norte  134605.36  272088.08  ...   8733455.36  2660065804.91
# 25 Paraíba               97352.78  368130.43  ...  12517894.05  2614895825.09
# 26 Pernambuco           400640.85 1088340.42  ...  39472738.81  8580915668.43
# 27 Alagoas              104243.75  174024.90  ...   8180887.21  2236401471.26
# 28 Sergipe               27453.63   78565.19  ...   3081081.42  1215843416.10
# 29 Bahia                135146.36  448349.75  ...  31314602.44  9791496136.10
# 31 Minas Gerais         971394.37 2861781.50  ...  79780838.00 20418205467.78
# 32 Espírito Santo        57408.11  284224.80  ...  15606368.11  3405838975.80
# 33 Rio de Janeiro       469469.34  921646.57  ...  49149884.48 10337229379.18
# 35 São Paulo           1665349.90 4434168.64  ... 177408317.71 41386533231.31
# 41 Paraná               554800.22 1431708.01  ...  43480729.07 14681341476.16
# 42 Santa Catarina       693955.05 1092964.12  ...  19375822.56  7834872054.38
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  37798832.80 12764274442.95
# 50 Mato Grosso do Sul   199556.12  573675.41  ...   4035989.77  2324515373.43
# 51 Mato Grosso           63562.50  232444.62  ...   8835890.09  2180110047.69
# 52 Goiás                179395.82  418053.58  ...  24867001.02  4973505000.10
# 53 Distrito Federal     191951.47  769966.25  ...  14731938.43  2592308843.05
#
# [27 rows x 165 columns]

# %%
usaveis.index
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
norte = ['Norte']*7
nordeste = ['Nordeste']*9
sudeste = ['Sudeste']*4
sul = ['Sul']*3
centro_oeste = ['Centro-Oeste']*4

regiao = norte + nordeste + sudeste + sul + centro_oeste
regiao
# Out:
# ['Norte',
#  'Norte',
#  'Norte',
#  'Norte',
#  'Norte',
#  'Norte',
#  'Norte',
#  'Nordeste',
#  'Nordeste',
#  'Nordeste',
#  'Nordeste',
#  'Nordeste',
#  'Nordeste',
#  'Nordeste',
#  'Nordeste',
#  'Nordeste',
#  'Sudeste',
#  'Sudeste',
#  'Sudeste',
#  'Sudeste',
#  'Sul',
#  'Sul',
#  'Sul',
#  'Centro-Oeste',
#  'Centro-Oeste',
#  'Centro-Oeste',
#  'Centro-Oeste']

# %%
usaveis_regiao = usaveis
usaveis_regiao.insert(0, 'Regiao', regiao)
usaveis_regiao
# Out:
#                               Regiao   2007/Ago  ...     2021/Mar          total
# Unidade da Federação                             ...
# 11 Rondônia                    Norte    4209.37  ...   4732441.04   996410650.35
# 12 Acre                        Norte   10470.07  ...   1137341.65   450047246.65
# 13 Amazonas                    Norte   35752.72  ...   6799060.80  1917245104.64
# 14 Roraima                     Norte    4785.91  ...   2381844.31   328876551.40
# 15 Pará                        Norte  181159.29  ...  13069564.31  4705290466.69
# 16 Amapá                       Norte   33672.74  ...    989155.40   309837994.87
# 17 Tocantins                   Norte    4113.76  ...    928756.84  1019990254.88
# 21 Maranhão                 Nordeste  385330.18  ...  17294509.11  3871010362.58
# 22 Piauí                    Nordeste  220788.25  ...   9542151.53  2280874839.37
# 23 Ceará                    Nordeste  357904.65  ...  17173151.55  6591825335.83
# 24 Rio Grande do Norte      Nordeste  134605.36  ...   8733455.36  2660065804.91
# 25 Paraíba                  Nordeste   97352.78  ...  12517894.05  2614895825.09
# 26 Pernambuco               Nordeste  400640.85  ...  39472738.81  8580915668.43
# 27 Alagoas                  Nordeste  104243.75  ...   8180887.21  2236401471.26
# 28 Sergipe                  Nordeste   27453.63  ...   3081081.42  1215843416.10
# 29 Bahia                    Nordeste  135146.36  ...  31314602.44  9791496136.10
# 31 Minas Gerais              Sudeste  971394.37  ...  79780838.00 20418205467.78
# 32 Espírito Santo            Sudeste   57408.11  ...  15606368.11  3405838975.80
# 33 Rio de Janeiro            Sudeste  469469.34  ...  49149884.48 10337229379.18
# 35 São Paulo                 Sudeste 1665349.90  ... 177408317.71 41386533231.31
# 41 Paraná                        Sul  554800.22  ...  43480729.07 14681341476.16
# 42 Santa Catarina                Sul  693955.05  ...  19375822.56  7834872054.38
# 43 Rio Grande do Sul             Sul 1049252.33  ...  37798832.80 12764274442.95
# 50 Mato Grosso do Sul   Centro-Oeste  199556.12  ...   4035989.77  2324515373.43
# 51 Mato Grosso          Centro-Oeste   63562.50  ...   8835890.09  2180110047.69
# 52 Goiás                Centro-Oeste  179395.82  ...  24867001.02  4973505000.10
# 53 Distrito Federal     Centro-Oeste  191951.47  ...  14731938.43  2592308843.05
#
# [27 rows x 166 columns]

# %%
usaveis
# Out:
#                               Regiao   2007/Ago  ...     2021/Mar          total
# Unidade da Federação                             ...
# 11 Rondônia                    Norte    4209.37  ...   4732441.04   996410650.35
# 12 Acre                        Norte   10470.07  ...   1137341.65   450047246.65
# 13 Amazonas                    Norte   35752.72  ...   6799060.80  1917245104.64
# 14 Roraima                     Norte    4785.91  ...   2381844.31   328876551.40
# 15 Pará                        Norte  181159.29  ...  13069564.31  4705290466.69
# 16 Amapá                       Norte   33672.74  ...    989155.40   309837994.87
# 17 Tocantins                   Norte    4113.76  ...    928756.84  1019990254.88
# 21 Maranhão                 Nordeste  385330.18  ...  17294509.11  3871010362.58
# 22 Piauí                    Nordeste  220788.25  ...   9542151.53  2280874839.37
# 23 Ceará                    Nordeste  357904.65  ...  17173151.55  6591825335.83
# 24 Rio Grande do Norte      Nordeste  134605.36  ...   8733455.36  2660065804.91
# 25 Paraíba                  Nordeste   97352.78  ...  12517894.05  2614895825.09
# 26 Pernambuco               Nordeste  400640.85  ...  39472738.81  8580915668.43
# 27 Alagoas                  Nordeste  104243.75  ...   8180887.21  2236401471.26
# 28 Sergipe                  Nordeste   27453.63  ...   3081081.42  1215843416.10
# 29 Bahia                    Nordeste  135146.36  ...  31314602.44  9791496136.10
# 31 Minas Gerais              Sudeste  971394.37  ...  79780838.00 20418205467.78
# 32 Espírito Santo            Sudeste   57408.11  ...  15606368.11  3405838975.80
# 33 Rio de Janeiro            Sudeste  469469.34  ...  49149884.48 10337229379.18
# 35 São Paulo                 Sudeste 1665349.90  ... 177408317.71 41386533231.31
# 41 Paraná                        Sul  554800.22  ...  43480729.07 14681341476.16
# 42 Santa Catarina                Sul  693955.05  ...  19375822.56  7834872054.38
# 43 Rio Grande do Sul             Sul 1049252.33  ...  37798832.80 12764274442.95
# 50 Mato Grosso do Sul   Centro-Oeste  199556.12  ...   4035989.77  2324515373.43
# 51 Mato Grosso          Centro-Oeste   63562.50  ...   8835890.09  2180110047.69
# 52 Goiás                Centro-Oeste  179395.82  ...  24867001.02  4973505000.10
# 53 Distrito Federal     Centro-Oeste  191951.47  ...  14731938.43  2592308843.05
#
# [27 rows x 166 columns]

# %% [markdown]
# #Desafio 6: Plotar o gráfico dos custos apenas dos estados da região sudeste e verificar se os picos de 2013/Fev teve comportamento similar em todos os demais estados da região.

# %%
import matplotlib.pyplot as plt


ax = ordenado_por_total.T[['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '32 Espírito Santo', '52 Goiás']].plot(cmap = 'plasma', grid = True, figsize = (10,7))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.ylabel('Valor total por atendimento')
plt.title('Valor total dos procedimentos hospitalares do SUS por unidade da federação', fontsize = 15)
plt.legend(bbox_to_anchor=(1, 0.8))
plt.show()

# %% [markdown]
# #Desafio 5.1: Buscar os casos de dengue no Brasil(época de maior número de casos e regiões mais atingidas) e ver se os picos de alguns estados em fevereiro e verão de modo geral, pode ser reflexos dos casos de Dengue.

# %%
dengue1 = dengue_pri.drop("Total", axis = 1)
dengue1 = dengue1.drop("2007", axis = 1)
dengue1 = dengue1.drop("2008", axis = 1)
dengue1
# Out:
#          UF de notificação    2009    2010    2011    2012    2013
# 0              11 Rondônia   18736   21434    2952    3194    8485
# 1                  12 Acre   19406   34316   18833    2259    2467
# 2              13 Amazonas    1669    7469   62247    5359   17545
# 3               14 Roraima    3222    7372    1297    1845     933
# 4                  15 Pará    7666   14832   16811   16327    8941
# 5                 16 Amapá    1720    3244    2765    1533    1683
# 6             17 Tocantins    4123    9008    9314   11795    8698
# 7              21 Maranhão    2200    5556   10247    5270    3489
# 8                 22 Piauí    4122    7069    9830   12326    5004
# 9                 23 Ceará    8081   20988   60635   54991   29974
# 10  24 Rio Grande do Norte    2730    6966   20854   26643   16663
# 11              25 Paraíba     967    6161   10944    8577   13114
# 12           26 Pernambuco    2961   33004   16070   31096    7159
# 13              27 Alagoas    4036   45169    7479   27488   10599
# 14              28 Sergipe    1906     588    2440    4622     822
# 15                29 Bahia  100398   44097   36347   48227   60381
# 16         31 Minas Gerais   55868  211040   34153   30121  415068
# 17       32 Espírito Santo   38880   23340   32872   11462   66468
# 18       33 Rio de Janeiro    8526   26691  158528  178515  208419
# 19            35 São Paulo   12203  199735  109272   28093  216398
# 20               41 Paraná    1631   37855   28894    4579   65907
# 21       42 Santa Catarina      60     182     139      93     305
# 22    43 Rio Grande do Sul      73    3602     331     155     448
# 23   50 Mato Grosso do Sul   13482   62856    6263    9277   78072
# 24          51 Mato Grosso   52464   36579    5008   32848   34912
# 25                52 Goiás   43690  100864   23145   23856  130542
# 26     53 Distrito Federal     913   15471    1607    1814   19738

# %%
dengue2 = dengue_seg.drop("Total", axis = 1)
dengue2 = dengue2.drop("UF de notificação", axis = 1)
dengue2 = dengue2.drop("2013", axis = 1)
dengue2 = dengue2.drop("2021", axis = 1)
dengue2
# Out:
#       2014    2015    2016   2017   2018    2019    2020
# 0     1994    2250    7916   2196    537     990    3940
# 1    28464    6067    2252   1885   7337   10192    8049
# 2     6318    3662    7516   3902   2322    3986    6195
# 3     1128    1110     210    284    111    1605     570
# 4     4540    7853   10883   7827   3778    5397    3732
# 5     2181    3400    1833    937    775     198      41
# 6     3677    8005    8011   4956   2929   13752    2272
# 7     2640    8003   23874   7193   2167    5641    2566
# 8     7699    7742    5298   5300   1944    8052    2220
# 9    22855   63596   49760  39439   4177   16306   23737
# 10   11576   22945   57103   7486  23822   32080    7169
# 11    5637   23188   36085   3844  11006   18876    6701
# 12   10498  111368   63028   7932  11238   38044   21499
# 13   13360   27294   19463   2928   2215   20998    2445
# 14    2260    9258    3621    623    236    6047    1905
# 15   13964   55557   67839  10100   9756   68203   83350
# 16   58256  192815  529737  26473  29337  478491   85243
# 17   19110   35408   43338   6897  10335   65046    7304
# 18    7846   73705   88427  11010  14857   32075    4502
# 19  226969  749772  203397   9468  18614  444381  210693
# 20   22775   45859   62970   2230   1426   45763  266213
# 21     137    4529    5157    191    185    2157   12016
# 22     150    1722    3198    183    128    1626    4017
# 23    3397   31990   47150   2322   5650   65381   52729
# 24    7183   21524   21377   9399   7294   11176   34768
# 25   92905  168934  129798  64080  91728  120548   59768
# 26   13609   10245   19603   4251   2482   39584   51375

# %%
import pandas as pd

dengue = pd.concat([dengue1, dengue2], axis = 1)

dengue = dengue.set_index("UF de notificação")

dengue
# Out:
#                           2009    2010    2011  ...   2018    2019    2020
# UF de notificação                               ...
# 11 Rondônia              18736   21434    2952  ...    537     990    3940
# 12 Acre                  19406   34316   18833  ...   7337   10192    8049
# 13 Amazonas               1669    7469   62247  ...   2322    3986    6195
# 14 Roraima                3222    7372    1297  ...    111    1605     570
# 15 Pará                   7666   14832   16811  ...   3778    5397    3732
# 16 Amapá                  1720    3244    2765  ...    775     198      41
# 17 Tocantins              4123    9008    9314  ...   2929   13752    2272
# 21 Maranhão               2200    5556   10247  ...   2167    5641    2566
# 22 Piauí                  4122    7069    9830  ...   1944    8052    2220
# 23 Ceará                  8081   20988   60635  ...   4177   16306   23737
# 24 Rio Grande do Norte    2730    6966   20854  ...  23822   32080    7169
# 25 Paraíba                 967    6161   10944  ...  11006   18876    6701
# 26 Pernambuco             2961   33004   16070  ...  11238   38044   21499
# 27 Alagoas                4036   45169    7479  ...   2215   20998    2445
# 28 Sergipe                1906     588    2440  ...    236    6047    1905
# 29 Bahia                100398   44097   36347  ...   9756   68203   83350
# 31 Minas Gerais          55868  211040   34153  ...  29337  478491   85243
# 32 Espírito Santo        38880   23340   32872  ...  10335   65046    7304
# 33 Rio de Janeiro         8526   26691  158528  ...  14857   32075    4502
# 35 São Paulo             12203  199735  109272  ...  18614  444381  210693
# 41 Paraná                 1631   37855   28894  ...   1426   45763  266213
# 42 Santa Catarina           60     182     139  ...    185    2157   12016
# 43 Rio Grande do Sul        73    3602     331  ...    128    1626    4017
# 50 Mato Grosso do Sul    13482   62856    6263  ...   5650   65381   52729
# 51 Mato Grosso           52464   36579    5008  ...   7294   11176   34768
# 52 Goiás                 43690  100864   23145  ...  91728  120548   59768
# 53 Distrito Federal        913   15471    1607  ...   2482   39584   51375
#
# [27 rows x 12 columns]

# %%
usaveis_2008 = usaveis[["2008/Jan", "2008/Fev", "2008/Mar", "2008/Abr", "2008/Mai", "2008/Jun", "2008/Jul", "2008/Ago", "2008/Set", "2008/Out", "2008/Nov", "2008/Dez"]]

usaveis_2008["2008"] = usaveis_2008.sum(axis=1)

usaveis_2008 = usaveis_2008[["2008"]]

usaveis_2008.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2008
# Unidade da Federação
# 11 Rondônia           29839972.31
# 12 Acre               24480534.65
# 13 Amazonas          102696703.00
# 14 Roraima            11886927.98
# 15 Pará              275035723.55

# %%
usaveis_2009 = usaveis[["2009/Jan", "2009/Fev", "2009/Mar", "2009/Abr", "2009/Mai", "2009/Jun", "2009/Jul", "2009/Ago", "2009/Set", "2009/Out", "2009/Nov", "2009/Dez"]]

usaveis_2009["2009"] = usaveis_2009.sum(axis=1)

usaveis_2009 = usaveis_2009[["2009"]]

usaveis_2009.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2009
# Unidade da Federação
# 11 Rondônia           44133812.42
# 12 Acre               26010824.00
# 13 Amazonas          106491315.75
# 14 Roraima            16929879.02
# 15 Pará              318534381.79

# %%
usaveis_2010 = usaveis[["2010/Jan", "2010/Fev", "2010/Mar", "2010/Abr", "2010/Mai", "2010/Jun", "2010/Jul", "2010/Ago", "2010/Set", "2010/Out", "2010/Nov", "2010/Dez"]]

usaveis_2010["2010"] = usaveis_2010.sum(axis=1)

usaveis_2010 = usaveis_2010[["2010"]]

usaveis_2010.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2010
# Unidade da Federação
# 11 Rondônia           53124212.75
# 12 Acre               29424692.81
# 13 Amazonas          114175777.25
# 14 Roraima            21019487.27
# 15 Pará              323475434.21

# %%
usaveis_2011 = usaveis[["2011/Jan", "2011/Fev", "2011/Mar", "2011/Abr", "2011/Mai", "2011/Jun", "2011/Jul", "2011/Ago", "2011/Set", "2011/Out", "2011/Nov", "2011/Dez"]]

usaveis_2011["2011"] = usaveis_2011.sum(axis=1)

usaveis_2011 = usaveis_2011[["2011"]]

usaveis_2011.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2011
# Unidade da Federação
# 11 Rondônia           53750792.13
# 12 Acre               33344038.83
# 13 Amazonas          120263314.00
# 14 Roraima            19167565.27
# 15 Pará              325157580.12

# %%
usaveis_2012 = usaveis[["2012/Jan", "2012/Fev", "2012/Mar", "2012/Abr", "2012/Mai", "2012/Jun", "2012/Jul", "2012/Ago", "2012/Set", "2012/Out", "2012/Nov", "2012/Dez"]]

usaveis_2012["2012"] = usaveis_2012.sum(axis=1)

usaveis_2012 = usaveis_2012[["2012"]]

usaveis_2012.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2012
# Unidade da Federação
# 11 Rondônia           52301055.10
# 12 Acre               34119460.43
# 13 Amazonas          122916860.05
# 14 Roraima            20131420.61
# 15 Pará              314077253.65

# %%
usaveis_2013 = usaveis[["2013/Jan", "2013/Fev", "2013/Mar", "2013/Abr", "2013/Mai", "2013/Jun", "2013/Jul", "2013/Ago", "2013/Set", "2013/Out", "2013/Nov", "2013/Dez"]]

usaveis_2013["2013"] = usaveis_2013.sum(axis=1)

usaveis_2013 = usaveis_2013[["2013"]]

usaveis_2013.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2013
# Unidade da Federação
# 11 Rondônia           66729484.10
# 12 Acre               33784031.38
# 13 Amazonas          124394890.31
# 14 Roraima            20992961.13
# 15 Pará              338360847.83

# %%
usaveis_2013 = usaveis[["2013/Jan", "2013/Fev", "2013/Mar", "2013/Abr", "2013/Mai", "2013/Jun", "2013/Jul", "2013/Ago", "2013/Set", "2013/Out", "2013/Nov", "2013/Dez"]]

usaveis_2013["2013"] = usaveis_2013.sum(axis=1)

usaveis_2013 = usaveis_2013[["2013"]]

usaveis_2013.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2013
# Unidade da Federação
# 11 Rondônia           66729484.10
# 12 Acre               33784031.38
# 13 Amazonas          124394890.31
# 14 Roraima            20992961.13
# 15 Pará              338360847.83

# %%
usaveis_2014 = usaveis[["2014/Jan", "2014/Fev", "2014/Mar", "2014/Abr", "2014/Mai", "2014/Jun", "2014/Jul", "2014/Ago", "2014/Set", "2014/Out", "2014/Nov", "2014/Dez"]]

usaveis_2014["2014"] = usaveis_2014.sum(axis=1)

usaveis_2014 = usaveis_2014[["2014"]]

usaveis_2014.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2014
# Unidade da Federação
# 11 Rondônia           82257890.98
# 12 Acre               35828191.77
# 13 Amazonas          125653016.96
# 14 Roraima            21581368.46
# 15 Pará              348668600.11

# %%
usaveis_2015 = usaveis[["2015/Jan", "2015/Fev", "2015/Mar", "2015/Abr", "2015/Mai", "2015/Jun", "2015/Jul", "2015/Ago", "2015/Set", "2015/Out", "2015/Nov", "2015/Dez"]]

usaveis_2015["2015"] = usaveis_2015.sum(axis=1)

usaveis_2015 = usaveis_2015[["2015"]]

usaveis_2015.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2015
# Unidade da Federação
# 11 Rondônia           88428027.15
# 12 Acre               37212305.04
# 13 Amazonas          151951929.99
# 14 Roraima            24253816.82
# 15 Pará              350527947.62

# %%
usaveis_2016 = usaveis[["2016/Jan", "2016/Fev", "2016/Mar", "2016/Abr", "2016/Mai", "2016/Jun", "2016/Jul", "2016/Ago", "2016/Set", "2016/Out", "2016/Nov", "2016/Dez"]]

usaveis_2016["2016"] = usaveis_2016.sum(axis=1)

usaveis_2016 = usaveis_2016[["2016"]]

usaveis_2016.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2016
# Unidade da Federação
# 11 Rondônia           91623322.06
# 12 Acre               38899136.05
# 13 Amazonas          148594724.62
# 14 Roraima            27134105.91
# 15 Pará              363094303.10

# %%
usaveis_2017 = usaveis[["2017/Jan", "2017/Fev", "2017/Mar", "2017/Abr", "2017/Mai", "2017/Jun", "2017/Jul", "2017/Ago", "2017/Set", "2017/Out", "2017/Nov", "2017/Dez"]]

usaveis_2017["2017"] = usaveis_2017.sum(axis=1)

usaveis_2017 = usaveis_2017[["2017"]]

usaveis_2017.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2017
# Unidade da Federação
# 11 Rondônia           96504132.64
# 12 Acre               38481037.98
# 13 Amazonas          161894361.65
# 14 Roraima            31447008.80
# 15 Pará              388200710.98

# %%
usaveis_2018 = usaveis[["2018/Jan", "2018/Fev", "2018/Mar", "2018/Abr", "2018/Mai", "2018/Jun", "2018/Jul", "2018/Ago", "2018/Set", "2018/Out", "2018/Nov", "2018/Dez"]]

usaveis_2018["2018"] = usaveis_2018.sum(axis=1)

usaveis_2018 = usaveis_2018[["2018"]]

usaveis_2018.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2018
# Unidade da Federação
# 11 Rondônia          102988676.57
# 12 Acre               35003946.70
# 13 Amazonas          178707383.73
# 14 Roraima            33427492.65
# 15 Pará              412284321.03

# %%
usaveis_2019 = usaveis[["2019/Jan", "2019/Fev", "2019/Mar", "2019/Abr", "2019/Mai", "2019/Jun", "2019/Jul", "2019/Ago", "2019/Set", "2019/Out", "2019/Nov", "2019/Dez"]]

usaveis_2019["2019"] = usaveis_2019.sum(axis=1)

usaveis_2019 = usaveis_2019[["2019"]]

usaveis_2019.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2019
# Unidade da Federação
# 11 Rondônia          106158004.05
# 12 Acre               35575765.00
# 13 Amazonas          188372182.21
# 14 Roraima            34576078.43
# 15 Pará              408031941.25

# %%
usaveis_2020 = usaveis[["2020/Jan", "2020/Fev", "2020/Mar", "2020/Abr", "2020/Mai", "2020/Jun", "2020/Jul", "2020/Ago", "2020/Set", "2020/Out", "2020/Nov", "2020/Dez"]]

usaveis_2020["2020"] = usaveis_2020.sum(axis=1)

usaveis_2020 = usaveis_2020[["2020"]]

usaveis_2020.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              2020
# Unidade da Federação
# 11 Rondônia          108171794.12
# 12 Acre               40286036.63
# 13 Amazonas          217748040.25
# 14 Roraima            36791970.14
# 15 Pará              448764859.15

# %%
import pandas as pd

hospital = pd.concat([usaveis_2008, usaveis_2009, usaveis_2010, usaveis_2011, usaveis_2012, usaveis_2013, usaveis_2014, usaveis_2015, usaveis_2016, usaveis_2017, usaveis_2018, usaveis_2019, usaveis_2020], axis = 1)

hospital
# Out:
#                                 2008          2009  ...          2019          2020
# Unidade da Federação                                ...
# 11 Rondônia              29839972.31   44133812.42  ...  106158004.05  108171794.12
# 12 Acre                  24480534.65   26010824.00  ...   35575765.00   40286036.63
# 13 Amazonas             102696703.00  106491315.75  ...  188372182.21  217748040.25
# 14 Roraima               11886927.98   16929879.02  ...   34576078.43   36791970.14
# 15 Pará                 275035723.55  318534381.79  ...  408031941.25  448764859.15
# 16 Amapá                 17412174.21   21438693.87  ...   29025429.19   30327388.77
# 17 Tocantins             63784432.00   76681528.44  ...   84288896.76   64827036.89
# 21 Maranhão             184371721.22  215443862.41  ...  366468563.01  381700176.21
# 22 Piauí                126950572.85  149095278.93  ...  208274730.37  224482821.52
# 23 Ceará                364666881.62  400766526.19  ...  617588829.25  636800080.91
# 24 Rio Grande do Norte  128129278.46  148478381.50  ...  263578271.05  281119996.63
# 25 Paraíba              154200619.27  185152755.61  ...  230913496.30  226111689.86
# 26 Pernambuco           384365029.51  443702553.69  ...  819485595.83  829650191.64
# 27 Alagoas              120782493.46  134990408.21  ...  206950712.48  206055705.24
# 28 Sergipe               58261431.56   69224288.60  ...  118548777.96  127649227.30
# 29 Bahia                542972452.04  587257587.34  ...  883280835.61  921710972.14
# 31 Minas Gerais        1100583314.01 1149168433.67  ... 1880474822.31 1925446850.51
# 32 Espírito Santo       149980101.76  172135196.48  ...  323984924.47  389996634.86
# 33 Rio de Janeiro       730765885.93  607673488.14  ...  952919836.74  997022179.78
# 35 São Paulo           2999487026.32 2489866865.82  ... 3495644382.86 3782233756.84
# 41 Paraná               683775631.04  794208127.74  ... 1512473093.46 1431045888.29
# 42 Santa Catarina       371472318.64  418249025.19  ...  756795943.87  799580035.50
# 43 Rio Grande do Sul    650692817.76  762244197.64  ... 1129914316.91 1207233297.69
# 50 Mato Grosso do Sul   115841480.71  135064369.89  ...  217545874.13  239406945.91
# 51 Mato Grosso          109306626.29  134692372.60  ...  189097219.86  209263049.13
# 52 Goiás                297138742.50  281962084.50  ...  431571078.85  472337715.96
# 53 Distrito Federal     140195882.56  166027294.09  ...  242814863.08  261552997.42
#
# [27 rows x 13 columns]

# %%
import matplotlib.pyplot as plt


ax = hospital.T[['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '32 Espírito Santo', '52 Goiás']].plot(cmap = 'plasma', grid = True, figsize = (10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.ylabel('Valor total por atendimento')
plt.title('Valor total dos procedimentos hospitalares do SUS por unidade da federação', fontsize = 15)
plt.legend(bbox_to_anchor=(1, 0.8))
plt.show()

# %%
import matplotlib.pyplot as plt


ax = dengue.T[['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '32 Espírito Santo', '52 Goiás']].plot(cmap = 'plasma', grid = True, figsize = (10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.ylabel('Notificação dos casos de dengue')
plt.title('Notificação dos casos de dengue', fontsize = 15)
plt.legend(bbox_to_anchor=(1, 0.8))
plt.show()

# %% [markdown]
# Os dados relacionados a dengue encontrados no DATASUS são anuais, por tanto, não deu para observar a sazonalidade.

# %% [markdown]
# #Desafio 7: Adicionar mais um estado novamente e tire suas conclusões sobre estados comparando com os demais. Tire suas conclusões e compartilhe.

# %%
import matplotlib.pyplot as plt


ax = hospital.T[['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '32 Espírito Santo', '13 Amazonas']].plot(cmap = 'plasma', grid = True, figsize = (10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.ylabel('Valor total por atendimento')
plt.title('Valor total dos procedimentos hospitalares do SUS por unidade da federação', fontsize = 15)
plt.legend(bbox_to_anchor=(1, 0.8))
plt.show()

# %%
import matplotlib.pyplot as plt


ax = dengue.T[['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '32 Espírito Santo', '13 Amazonas']].plot(cmap = 'plasma', grid = True, figsize = (10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.ylabel('Notificação dos casos de dengue')
plt.title('Notificação dos casos de dengue', fontsize = 15)
plt.legend(bbox_to_anchor=(1, 0.8))
plt.show()
